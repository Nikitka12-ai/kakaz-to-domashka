# %% [markdown]
# пункт1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %% [markdown]
# пункт 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Пункт 3

# %%
df = pd.read_csv('/content/drive/MyDrive/paddydataset.csv')
print("Инфа о датасете:")
df.info()
# Out:
# Инфа о датасете:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2789 entries, 0 to 2788
# Data columns (total 45 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Hectares                            2789 non-null   int64
#  1   Agriblock                           2789 non-null   object
#  2   Variety                             2789 non-null   object
#  3   Soil Types                          2789 non-null   object
#  4   Seedrate(in Kg)                     2789 non-null   int64
#  5   LP_Mainfield(in Tonnes)             2789 non-null   float64
#  6   Nursery                             2789 non-null   object
#  7   Nursery area (Cents)                2789 non-null   int64
#  8   LP_nurseryarea(in Tonnes)           2789 non-null   int64
#  9   DAP_20days                          2789 non-null   int64
#  10  Weed28D_thiobencarb                 2789 non-null   int64
# ...

# %% [markdown]
# Пункт 4 строки и столбцы

# %%
print(f"\nКоличество столбцов: {len(df.columns)}")
print("Названия столбцов:")
print(df.columns)
print(f"\nКоличество строк: {len(df)}")
print("Индексы строк:")
print(df.index)
# Out:
# Количество столбцов: 45
# Названия столбцов:
# Index(['Hectares ', 'Agriblock', 'Variety', 'Soil Types', 'Seedrate(in Kg)',
#        'LP_Mainfield(in Tonnes)', 'Nursery', 'Nursery area (Cents)',
#        'LP_nurseryarea(in Tonnes)', 'DAP_20days', 'Weed28D_thiobencarb',
#        'Urea_40Days', 'Potassh_50Days', 'Micronutrients_70Days',
#        'Pest_60Day(in ml)', '30DRain( in mm)', '30DAI(in mm)',
#        '30_50DRain( in mm)', '30_50DAI(in mm)', '51_70DRain(in mm)',
#        '51_70AI(in mm)', '71_105DRain(in mm)', '71_105DAI(in mm)',
#        'Min temp_D1_D30', 'Max temp_D1_D30', 'Min temp_D31_D60',
#        'Max temp_D31_D60', 'Min temp_D61_D90', 'Max temp_D61_D90',
#        'Min temp_D91_D120', 'Max temp_D91_D120',
#        'Inst Wind Speed_D1_D30(in Knots)', 'Inst Wind Speed_D31_D60(in Knots)',
#        'Inst Wind Speed_D61_D90(in Knots)',
#        'Inst Wind Speed_D91_D120(in Knots)', 'Wind Direction_D1_D30',
#        'Wind Direction_D31_D60', 'Wind Direction_D61_D90',
# ...

# %% [markdown]
# Пункт 5 Замена категориальных данных количественными

# %%
print("\n" + "="*60)
print("="*60)

# есть категориальные
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

print(f"\n ДО ЗАМЕНЫ:")
print(f"Найдено категориальных столбцов: {len(categorical_columns)}")
print(f"Имена столбцов: {categorical_columns}")

if len(categorical_columns) > 0:
    print("\nПервые 5 ДО замены:")
    print(df[categorical_columns].head())

if len(categorical_columns) > 0:


    le_dict = {}  # Словарь для сохранения encoder
    for col in categorical_columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
        le_dict[col] = le


print("\nПОСЛЕ ЗАМЕНЫ")

if len(categorical_columns) > 0:
    print(f"\nПервые 5 ПОСЛЕ замены:")
    print(df[categorical_columns].head())
# Out:
# ...
#
#  ДО ЗАМЕНЫ:
# Найдено категориальных столбцов: 8
# Имена столбцов: ['Agriblock', 'Variety', 'Soil Types', 'Nursery', 'Wind Direction_D1_D30', 'Wind Direction_D31_D60', 'Wind Direction_D61_D90', 'Wind Direction_D91_D120']
#
# Первые 5 ДО замены:
#       Agriblock      Variety Soil Types Nursery Wind Direction_D1_D30  \
# 0     Cuddalore        CO_43   alluvial     dry                    SW
# 1   Kurinjipadi      ponmani       clay     wet                    NW
# 2       Panruti  delux ponni   alluvial     dry                   ENE
# 3  Kallakurichi        CO_43       clay     wet                     W
# 4  Sankarapuram      ponmani   alluvial     dry                   SSE
#
#   Wind Direction_D31_D60 Wind Direction_D61_D90 Wind Direction_D91_D120
# 0                      W                    NNW                     WSW
# 1                      S                     SE                     SSE
# 2                     NE                    NNE                       W
# ...

# %% [markdown]
# Пункт 6

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Paddy yield(in Kg)', bins=30, kde=False, color='coral', alpha=0.7)
plt.title('Распределение урожайности риса', fontsize=16, fontweight='bold')
plt.xlabel('Урожайность (кг)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Seedrate(in Kg)', bins=30, kde=False, color='skyblue', alpha=0.7)
plt.title('Распределение нормы высева семян', fontsize=16, fontweight='bold')
plt.xlabel('Норма высева (кг)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Urea_40Days', bins=30, kde=False, color='lightgreen', alpha=0.7)
plt.title('Распределение внесения мочевины на 40-й день', fontsize=16, fontweight='bold')
plt.xlabel('Мочевина (кг)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Пункт 6 : График Seaborn

# %%
# Тепловая карта тут только числовые
sns.heatmap(df.corr(numeric_only = True));

sns.set_style('whitegrid')
sns.set_palette('husl')

plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Paddy yield(in Kg)', bins=30, kde=True, color='coral', alpha=0.7)
plt.title('Распределение урожайности риса', fontsize=16, fontweight='bold')
plt.xlabel('Урожайность (кг)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Seedrate(in Kg)', bins=30, kde=True, color='skyblue', alpha=0.7)
plt.title('Распределение нормы высева семян', fontsize=16, fontweight='bold')
plt.xlabel('Норма высева (кг)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Urea_40Days', bins=30, kde=True, color='lightgreen', alpha=0.7)
plt.title('Распределение внесения мочевины на 40-й день', fontsize=16, fontweight='bold')
plt.xlabel('Мочевина (кг)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.tight_layout()
plt.show()
